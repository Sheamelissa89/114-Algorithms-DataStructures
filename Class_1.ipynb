# %%
def count_even_numbers(collection):
    total = 0

    for number in collection:
        if number % 2 == 0:
            total += 1

    return total

# %%
numbers = [3, 5, 27, 20, 6, 3.5, 60]

total = count_even_numbers(numbers)

print(f"total = {total}")
# Out:
# total = 3

# %%
numbers = ["1", "2"]

total = count_even_numbers(numbers)

print(f"total = {total}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 numbers = ["1", "2"]
#       2
# ----> 3 total = count_even_numbers(numbers)
#       4
#       5 print(f"total = {total}")
#
# Cell In[6], line 5, in count_even_numbers(collection)
#       1 def count_even_numbers(collection):
#       2     total = 0
#       3
#       4     for number in collection:
# ----> 5         if number % 2 == 0:
#       6             total += 1
#       7
#       8     return total
#
# TypeError: not all arguments converted during string formatting
